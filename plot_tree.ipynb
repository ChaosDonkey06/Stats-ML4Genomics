# %%
library(tidyverse)
library(ggtree)
# Out:
# -- Attaching core tidyverse packages ------------------------ tidyverse 2.0.0 --
# v dplyr     1.1.4          v readr     2.1.5
# v forcats   1.0.0          v stringr   1.5.1
# v ggplot2   3.5.1          v tibble    3.2.1.9024
# v lubridate 1.9.3          v tidyr     1.3.1
# v purrr     1.0.2
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# i Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ggtree v3.12.0 For help: https://yulab-smu.top/treedata-book/
#
# If you use the ggtree package suite in published research, please cite
# the appropriate paper(s):
#
# Guangchuang Yu, David Smith, Huachen Zhu, Yi Guan, Tommy Tsan-Yuk Lam.
# ggtree: an R package for visualization and annotation of phylogenetic
# trees with their covariates and other associated data. Methods in
# ...

# %%
raw_tree <- read.tree("data/dengue/tree/tree_raw.nwk")
raw_tree
# Out:
# Phylogenetic tree with 2924 tips and 2922 internal nodes.
#
# Tip labels:
#   China/MN018327/DENV1/2017, China/MN018291/DENV1/2017, BKK/00738/14/DENV1/2014, China/MN018317/DENV1/2016, BKK/00758/14/DENV1/2014, Malaysia/JN697057/DENV1/2005, ...
#
# Rooted; includes branch lengths.

# %%
tree <- read.tree("data/dengue/tree/tree.nwk")
tree
# Out:
# Phylogenetic tree with 2924 tips and 2601 internal nodes.
#
# Tip labels:
#   BKK/04634/98/DENV4/1998, BKK/04786/98/DENV4/1998, BKK/04390/99/DENV4/1999, BKK/00049/97/DENV4/1997, BKK/02739/97/DENV4/1997, BKK/00646/05/DENV4/2005, ...
# Node labels:
#   NODE_0000013, NODE_0001650, NODE_0001651, NODE_0001652, NODE_0001653, NODE_0001654, ...
#
# Rooted; includes branch lengths.

# %%
ggtree(tree, ignore.negative.edge=TRUE) #+ scale_x_continuous(trans='log10')

options(repr.plot.width=15, repr.plot.height=14)
# Out:
# ! The tree contained negative edge lengths. If you want to ignore the edges,
# you can set `options(ignore.negative.edge=TRUE)`, then re-run ggtree.
#
# Warning message in stat_tree(data = data, mapping = mapping, geom = "segment", position = position, :
# "Ignoring unknown parameters: `ignore.negative.edge`"
# Warning message in stat_tree(data = data, mapping = mapping, geom = "segment", position = position, :
# "Ignoring unknown parameters: `ignore.negative.edge`"
# plot without title

# %%
ggtree(tree, ignore.negative.edge=TRUE) #+ scale_x_continuous(trans='log10')

options(repr.plot.width=15, repr.plot.height=14)
# Out:
# ! The tree contained negative edge lengths. If you want to ignore the edges,
# you can set `options(ignore.negative.edge=TRUE)`, then re-run ggtree.
#
# Warning message in stat_tree(data = data, mapping = mapping, geom = "segment", position = position, :
# "Ignoring unknown parameters: `ignore.negative.edge`"
# Warning message in stat_tree(data = data, mapping = mapping, geom = "segment", position = position, :
# "Ignoring unknown parameters: `ignore.negative.edge`"
# plot without title

# %%
ggtree(tree, layout="circular")#+ geom_tippoint()
# Out:
# ! The tree contained negative edge lengths. If you want to ignore the edges,
# you can set `options(ignore.negative.edge=TRUE)`, then re-run ggtree.
# plot without title

# %%
ggtree(tree, layout="equal_angle")

options(repr.plot.width=8, repr.plot.height=8)
# Out:
# plot without title

# %%
getMRCA(tree, c('BKK/04634/98/DENV4/1998', 'BKK/04786/98/DENV4/1998'))
# Out:
# Error in getMRCA(tree, c("BKK/04634/98/DENV4/1998", "BKK/04786/98/DENV4/1998")): could not find function "getMRCA"
# Traceback:

# %%
tree
# Out:
# Phylogenetic tree with 2924 tips and 2601 internal nodes.
#
# Tip labels:
#   BKK/04634/98/DENV4/1998, BKK/04786/98/DENV4/1998, BKK/04390/99/DENV4/1999, BKK/00049/97/DENV4/1997, BKK/02739/97/DENV4/1997, BKK/00646/05/DENV4/2005, ...
# Node labels:
#   NODE_0000013, NODE_0001650, NODE_0001651, NODE_0001652, NODE_0001653, NODE_0001654, ...
#
# Rooted; includes branch lengths.
